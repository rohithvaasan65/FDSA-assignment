# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithvaasan65/FDSA-assignment/blob/main/FDSA_RESUMBIT_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
st_data_2018 = pd.read_csv("/content/science_tech_2018.csv")
st_data_2018.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           0.049514
# 2         Algeria                                                NaN
# 3  American Samoa                                                NaN
# 4         Andorra                                          28.460560
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                               591717.0                         3713.0
# 2                                    NaN                         9490.0
# 3                                    NaN                            NaN
# 4                             33913480.0                         1180.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
st_data_2018.shape
# Out:
# (219, 10)

# %%
st_data_2009 = pd.read_csv("/content/science_tech_2009.csv")
st_data_2009.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           1.328024
# 2         Algeria                                           0.653887
# 3  American Samoa                                                NaN
# 4         Andorra                                          12.192161
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                             10128935.0                         3456.0
# 2                              4616076.0                         5345.0
# 3                                    NaN                            NaN
# 4                             10402350.0                          785.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
st_data_2009.shape
# Out:
# (219, 10)

# %%
st_data_2009.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
st_data_2009.size
# Out:
# 2190

# %% [markdown]
# CLEANING DATA

# %%
st_data_2018.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     87
# High-technology exports (current US$)                   88
# Trademark applications, total                           86
# Trademark applications, direct resident                 91
# Trademark applications, direct nonresident              90
# Patent applications, residents                         101
# Patent applications, nonresidents                      100
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        146
# dtype: int64

# %%
st_data_2018_clean = st_data_2018.dropna()
st_data_2018_clean.shape
# Out:
# (51, 10)

# %%
st_data_2009.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     88
# High-technology exports (current US$)                   88
# Trademark applications, total                          108
# Trademark applications, direct resident                118
# Trademark applications, direct nonresident             118
# Patent applications, residents                         126
# Patent applications, nonresidents                      118
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        122
# dtype: int64

# %%
st_data_2009_clean = st_data_2009.dropna()
st_data_2009_clean.shape
# Out:
# (56, 10)

# %%
st_data_2018_clean.describe()
# Out:
#        High-technology exports (% of manufactured exports)  \
# count                                          51.000000
# mean                                           11.873699
# std                                             7.901769
# min                                             0.042349
# 25%                                             5.336634
# 50%                                            10.367695
# 75%                                            17.102852
# max                                            36.346865
#
#        High-technology exports (current US$)  Trademark applications, total  \
# count                           5.100000e+01                      51.000000
# mean                            2.569787e+10                   44515.294118
# std                             4.869023e+10                   85393.786483
# min                             1.150510e+05                    1974.000000
# ...

# %%
from pandas.io.formats import style
pd.set_option('display.float_format',lambda x: '%.3f' %x)
st_data_2018_clean.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_bdfac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdfac_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_bdfac_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_bdfac_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_bdfac_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_bdfac_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_bdfac_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_bdfac_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
st_data_2018_clean.corr(method='pearson').style.background_gradient(cmap='viridis')
# Out:
# <ipython-input-27-94797d13a162>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   st_data_2018_clean.corr(method='pearson').style.background_gradient(cmap='viridis')
# <style type="text/css">
# #T_c1ce0_row0_col0, #T_c1ce0_row1_col1, #T_c1ce0_row2_col2, #T_c1ce0_row3_col3, #T_c1ce0_row4_col4, #T_c1ce0_row5_col5, #T_c1ce0_row6_col6, #T_c1ce0_row7_col7, #T_c1ce0_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c1ce0_row0_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_c1ce0_row0_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_c1ce0_row0_col3, #T_c1ce0_row8_col1, #T_c1ce0_row8_col6 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_c1ce0_row0_col4, #T_c1ce0_row8_col7 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# ...

# %%
import scipy.stats as stats

# %%
a= st_data_2009_clean['Patent applications, nonresidents']
b= st_data_2018_clean['Patent applications, nonresidents']
stats.ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=-0.04471790792368344, pvalue=0.9644170934929569)

# %%
for i in range(1,len(columns)):
  a=st_data_2009_clean[columns[i]]
  b=st_data_2018_clean[columns[i]]
  print(columns[i])
  print(stats.ttest_ind(a,b))

# %% [markdown]
# Z-test using formula

# %%
import math
import numpy as np
from numpy.random import randn
from statsmodels.stats.weightstats import ztest

mean_iq = 110
sd_iq = 15/math.sqrt(50)
alpha =0.05
null_mean =100
data = sd_iq*randn(50)+mean_iq


print('mean=%.2f stdv=%.2f' % (np.mean(data), np.std(data)))


ztest_Score, p_value= ztest(data,value = null_mean, alternative='larger')


if(p_value < alpha):
  print("Reject Null Hypothesis")
else:
  print("Accept NUll Hypothesis")
# Out:
# mean=110.36 stdv=2.29
# Reject Null Hypothesis

# %% [markdown]
#  Ztest using dataset

# %%
import pandas as pd
from statsmodels.stats import weightstats as stests


df = pd.read_csv("/content/Covid Data.csv")


df[['PREGNANT','INTUBED']].describe()


ztest ,propability_value = stests.ztest(df['INTUBED'], x2=None, value=146)
print(float(propability_value))


if propability_value<0.05:
    print("Null hyphothes is rejected , Alternative hyphothesis accepted")
else:
    print("Null hyphothesis accepted , Alternative hyphothesis rejected")
# Out:
# 0.0
# Null hyphothes is rejected , Alternative hyphothesis accepted

# %% [markdown]
# T-test(one sample)

# %%
import numpy as np
from scipy import stats 
from numpy.random import seed
from numpy.random import randn
from numpy.random import normal
from scipy.stats import ttest_1samp

seed=(1)
sample =normal(150,7,20)
print('Sample: ', sample)
# Out:
# Sample:  [137.72959999 142.80889572 145.32098152 138.90585251 152.82958986
#  151.65066713 139.09538647 148.50861516 158.13153841 158.24400724
#  151.1519591  158.03005101 166.1069936  148.72961884 160.19251428
#  156.20214345 153.80782638 143.63212032 152.24790225 159.86565751]

# %% [markdown]
# Two tail Z-test

# %%
from statsmodels.stats.weightstats import ztest as ztest

A = [82, 84, 85, 89, 91, 91, 92, 94, 99, 99,
         105, 109, 109, 109, 110, 112, 112, 113, 114, 114]

B = [90, 91, 91, 91, 95, 95, 99, 99, 108, 109,
         109, 114, 115, 116, 117, 117, 128, 129, 130, 133]

ztest(A, B, value=0)
# Out:
# (-1.9953236073282115, 0.046007596761332065)
